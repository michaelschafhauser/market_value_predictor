# %%
import pandas as pd

df = pd.read_csv("market_value_predictor/raw_data/transfer_history_combined.csv")
df.head()
# Out:
#    Unnamed: 0              club_name           player_name   age  \
# 0           0  FC Girondins Bordeaux       Zinédine Zidane  20.0
# 1           1  FC Girondins Bordeaux         Laurent Croci  27.0
# 2           2  FC Girondins Bordeaux        Philippe Lucas  28.0
# 3           3  FC Girondins Bordeaux         Márcio Santos  22.0
# 4           4  FC Girondins Bordeaux  Jean-Francois Daniel  28.0
#
#              position club_involved_name     fee transfer_movement  \
# 0  Attacking Midfield             Cannes  £6.30m                in
# 1  Defensive Midfield         FC Sochaux       ?                in
# 2  Defensive Midfield         FC Sochaux       ?                in
# 3         Centre-Back           Botafogo       ?                in
# 4    Central Midfield             Cannes       ?                in
#
#   transfer_period  fee_cleaned league_name  year     season
# 0          Summer          6.3     Ligue 1  1992  1992/1993
# ...

# %%
df1=df[df["fee_cleaned"] >= 0.001]
df1
# Out:
#         Unnamed: 0              club_name        player_name   age  \
# 0                0  FC Girondins Bordeaux    Zinédine Zidane  20.0
# 167            167   RC Strasbourg Alsace     Michael Hughes  20.0
# 168            168   RC Strasbourg Alsace  Tomasz Frankowski  17.0
# 183            183              AS Monaco   Jürgen Klinsmann  27.0
# 190            190              AS Monaco        George Weah  25.0
# ...            ...                    ...                ...   ...
# 174312         443           RCD Mallorca       Ante Budimir  30.0
# 174330         461         Rayo Vallecano        Fran García  22.0
# 174331         462         Rayo Vallecano        Randy Nteka  23.0
# 174332         463         Rayo Vallecano         Pathé Ciss  27.0
# 174341         472         Rayo Vallecano     Luis Advíncula  31.0
#
#                   position club_involved_name      fee transfer_movement  \
# 0       Attacking Midfield             Cannes   £6.30m                in
# ...

# %%
df2=df1[df1["year"] >= 2014]
df2
# Out:
#         Unnamed: 0              club_name      player_name   age  \
# 117340           0              SC Bastia   Luka Kikabidze  19.0
# 117364          24              SC Bastia     Wahbi Khazri  23.0
# 117381          41  FC Girondins Bordeaux     Wahbi Khazri  23.0
# 117382          42  FC Girondins Bordeaux   Diego Contento  24.0
# 117383          43  FC Girondins Bordeaux  Nicolas Pallois  26.0
# ...            ...                    ...              ...   ...
# 174312         443           RCD Mallorca     Ante Budimir  30.0
# 174330         461         Rayo Vallecano      Fran García  22.0
# 174331         462         Rayo Vallecano      Randy Nteka  23.0
# 174332         463         Rayo Vallecano       Pathé Ciss  27.0
# 174341         472         Rayo Vallecano   Luis Advíncula  31.0
#
#                   position club_involved_name      fee transfer_movement  \
# 117340       Left Midfield      FC Locomotive   £90Th.                in
# ...
